# %%
# Importing Libraries
import pandas as pd
import numpy as np
from pandas import read_csv
from matplotlib import pyplot as plt
from pandas.plotting import lag_plot
from statsmodels.graphics.tsaplots import plot_acf
from pandas import DataFrame
from pandas import Grouper

# %%
series = read_csv('C:/Users\Moin Dalvi\Documents\Data Science Material\Data Science\Python\Datasets/daily-minimum-temperatures.csv', header = 0, index_col=0, parse_dates=True)
series
# Out:
#             Temp
# Date
# 1981-01-01  20.7
# 1981-01-02  17.9
# 1981-01-03  18.8
# 1981-01-04  14.6
# 1981-01-05  15.8
# ...          ...
# 1990-12-27  14.0
# 1990-12-28  13.6
# 1990-12-29  13.5
# 1990-12-30  15.7
# 1990-12-31  13.0
#
# [3650 rows x 1 columns]

# %% [markdown]
# ### Line plot

# %%
# Creat a Line plot
series.plot(figsize=(16,9))
plt.show()

# %% [markdown]
# ### Histogram and Density Plots

# %%
series.hist(figsize=(12,8))
plt.show()

# %%
# create a density plot
from pandas import read_csv
from matplotlib import pyplot
series.plot(kind='kde', figsize=(12,8))
plt.show()

# %% [markdown]
# #### Box and Whisker Plots by Interval

# %%
# create a boxplot of yearly data

groups = series.groupby(Grouper(freq='A'))
years = DataFrame()
for name, group in groups:
    years[name.year] = (group.values.flatten())
years
# Out:
#      1981  1982  1983  1984  1985  1986  1987  1988  1989  1990
# 0    20.7  17.0  18.4  19.5  13.3  12.9  12.3  15.3  14.3  14.8
# 1    17.9  15.0  15.0  17.1  15.2  13.8  13.8  14.3  17.4  13.3
# 2    18.8  13.5  10.9  17.1  13.1  10.6  15.3  13.5  18.5  15.6
# 3    14.6  15.2  11.4  12.0  12.7  12.6  15.6  15.0  16.8  14.5
# 4    15.8  13.0  14.8  11.0  14.6  13.7  16.2  13.6  11.5  14.3
# ..    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 360  15.5  15.3  13.9  12.2  11.5  14.6  16.2   9.5  13.3  14.0
# 361  13.3  16.3  11.1  12.0  10.8  14.2  14.2  12.9  11.7  13.6
# 362  15.6  15.8  16.1  12.6  12.0  13.2  14.3  12.9  10.4  13.5
# 363  15.2  17.7  20.4  16.0  16.3  11.7  13.3  14.8  14.4  15.7
# 364  17.4  16.3  18.0  16.4  14.4  17.2  16.7  14.1  12.7  13.0
#
# [365 rows x 10 columns]

# %%
years.boxplot(figsize=(12,8))
plt.show()

# %% [markdown]
# ### Lag plot

# %%
# create a scatter plot
for i in [1, 30, 60, 90, 120, 150, 180, 210, 240, 270, 300, 330, 365]:
    #plt.figure(figsize=(12,8))
    lag_plot(series, lag=i)
    plt.show()

# %% [markdown]
# ### Autocorrealtion plot

# %%
# create an autocorrelation plot
n, m = 12, 8

with plt.rc_context():
    plt.rc("figure", figsize=(n,m))

    plt.figure(figsize=(12,8))
    plot_acf(series,lags=365)
    plt.show()
